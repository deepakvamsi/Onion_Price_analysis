# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.models import ColumnDataSource
import plotly.express as px
import glob

#pandas_bokeh.output_file("Interactive Plot.html")


file=glob.glob("Onion_20*.csv")

for filename in file:
    df = pd.read_csv(filename,usecols=range(0, 8), low_memory=False) 
    dataframe = df.loc[df['District'] == 'Kurnool']
    dataframe['Arrival_Date'] = pd.to_datetime(dataframe['Arrival_Date'])
    dframe = dataframe.sort_values(by='Arrival_Date', ascending=True)
    #dframe.to_csv('onion_data.csv')
    #daframe = pd.read_csv('onion_data.csv',usecols=range(0, 9),low_memory=False)
    #line_in = figure(df, values = 'Arrival_Date', title = "Onion Prices Comparsion between years", legend= "top_left", Ylabel= "Maximum")
    fig = px.bar(dframe, x = 'Arrival_Date', y = 'Max', hover_data=['Min', 'Market', 'Commodity', 'Variety'], color='Market', title='Onion quintal(100kgs) Price over time', labels={'Max':'Maximum Price/100Kg'}, width=1400,height=1000)
    fig.show()

    
#melt_df = pd.melt(list_of_dfs,id_vars= ['state'], value_vars=['arrival_date', 'district', 'market', 'min', 'max'])
#melt_df.head()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="785c15c1-ca6b-4cbf-8c28-f63af60ea7e1" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("785c15c1-ca6b-4cbf-8c28-f63af60ea7e1")) {
#                     Plotly.newPlot(
#                         '785c15c1-ca6b-4cbf-8c28-f63af60ea7e1',
#                         [{"alignmentgroup": "True", "customdata": [["600", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["750", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1250", "Alur", "Onion", "Beelary-Red"], ["1280", "Alur", "Onion", "Beelary-Red"], ["1250", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Al ...
# <div>
#
#
#             <div id="7b2147f7-c348-4cfc-b724-b39a3d43cc4e" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b2147f7-c348-4cfc-b724-b39a3d43cc4e")) {
#                     Plotly.newPlot(
#                         '7b2147f7-c348-4cfc-b724-b39a3d43cc4e',
#                         [{"alignmentgroup": "True", "customdata": [["1300", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["1400", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["1200", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["2000", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["1200", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["1200", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["2500", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["600", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "Onion", "Local"], ["800", "Pattikonda", "Onion", "Local"], ["700", "Pattikonda", "O ...
# <div>
#
#
#             <div id="64da9840-f7c1-4e6a-89f9-15f8685f63d1" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("64da9840-f7c1-4e6a-89f9-15f8685f63d1")) {
#                     Plotly.newPlot(
#                         '64da9840-f7c1-4e6a-89f9-15f8685f63d1',
#                         [{"alignmentgroup": "True", "customdata": [[200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [156, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [188, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [167, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [300, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [250, "Alur", "Onion", "Beelary-Red"], [250, "Alur", "Onion", "Beelary-Red"], [250, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [233, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [212, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Local"], [233, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [222, "Alur", "Onion", "Beelary-Red"], [192, "Alur", "Onion", "Beelary-Red"], [180, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Beelary-Red"], [250, "Alur", "Onion", "Beelary-Red"], [500, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [167, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [176, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [150, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Local"], [200, "Alur", "Onion", "Local"], [192, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [167, "Alur", "Onion", "Beelary-Red"], [178, "Alur", "Onion", "Beelary-Red"], [214, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [222, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [175, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [176, "Alur", "Onion", "Beelary-Red"], [150, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [222, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [222, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [178, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [222, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Alur", "Onion", "Beelary-Red"], [200, "Al ...
# <div>
#
#
#             <div id="ea5cadb6-7ef6-4957-9784-b55a9620a09f" class="plotly-graph-div" style="height:1000px; width:1400px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ea5cadb6-7ef6-4957-9784-b55a9620a09f")) {
#                     Plotly.newPlot(
#                         'ea5cadb6-7ef6-4957-9784-b55a9620a09f',
#                         [{"alignmentgroup": "True", "customdata": [["1800", "Alur", "Onion", "Beelary-Red"], ["2000", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["500", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["400", "Alur", "Onion", "Beelary-Red"], ["400", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["2000", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["1400", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["2000", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["1700", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["1700", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["1700", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1100", "Alur", "Onion", "Beelary-Red"], ["1200", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["1800", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["400", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["1700", "Alur", "Onion", "Beelary-Red"], ["1500", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["1000", "Alur", "Onion", "Beelary-Red"], ["1300", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["900", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["2000", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["400", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["700", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["2000", "Alur", "Onion", "Beelary-Red"], ["1600", "Alur", "Onion", "Beelary-Red"], ["800", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["500", "Alur", "Onion", "Beelary-Red"], ["500", "Alur", "Onion", "Beelary-Red"], ["600", "Alur", "Onion", "Beelary-Red"], ["60 ...
